# %%
import matplotlib.pyplot as plt
import mglearn
mglearn.plots.plot_knn_classification(n_neighbors=1)
plt.title('forge_one_neghibors')
# Out:
# C:\Users\Raghav Jha\Anaco\lib\site-packages\sklearn\utils\deprecation.py:85: DeprecationWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=DeprecationWarning)
# Text(0.5, 1.0, 'forge_one_neghibors')

# %%
#three closet neghibors
mglearn.plots.plot_knn_classification(n_neighbors=3)
# Out:
# C:\Users\Raghav Jha\Anaco\lib\site-packages\sklearn\utils\deprecation.py:85: DeprecationWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=DeprecationWarning)

# %%
from sklearn.model_selection import train_test_split
X,y=mglearn.datasets.make_forge()
X_train,y_train,X_test,y_test=train_test_split(X,y,random_state=0)
# Out:
# C:\Users\Raghav Jha\Anaco\lib\site-packages\sklearn\utils\deprecation.py:85: DeprecationWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=DeprecationWarning)

# %%
from sklearn.neighbors import  KNeighborsClassifier
clf= KNeighborsClassifier(n_neighbors=3)

# %%
clf
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

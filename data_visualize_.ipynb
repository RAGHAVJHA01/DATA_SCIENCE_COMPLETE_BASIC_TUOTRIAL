# %%
l1=['ram','bam','kam','sam','naam']
l2=['ramm','nammm','raam']
#l1[::-1]
c=
c=[i+j for i,j in zip( l1,l2)]
#print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-7d626b64251c> in <module>
#       2 l2=['ramm','nammm','raam']
#       3 #l1[::-1]
# ----> 4 c=len[11]
#       5 #c=[i+j for i,j in zip( l1,l2)]
#       6 #print(c)
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
l1=len(l1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-8c58603c848b> in <module>
# ----> 1 l1=len(l1)
#
# TypeError: object of type 'int' has no len()

# %%
l1
# Out:
# 5

# %%
l1.append(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-b0551c3ebf3a> in <module>
# ----> 1 l1.append(2)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
l1
# Out:
# 5

# %%
l1.remove(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-cebbfa082e32> in <module>
# ----> 1 l1.remove(2)
#
# AttributeError: 'int' object has no attribute 'remove'

# %%
l1
# Out:
# 5

# %%
z=[1,2,3,4,5]
c=zip[l1,z]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-44b99a8a4161> in <module>
#       1 z=[1,2,3,4,5]
# ----> 2 c=zip[l1,z]
#
# TypeError: 'type' object is not subscriptable

# %%
c

# %%
l1.difference(l2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-4c5cbfeb5f06> in <module>
# ----> 1 l1.difference(l2)
#
# AttributeError: 'int' object has no attribute 'difference'

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#sns.load_dataset('tips')
tips = sns.load_dataset("tips")

# %%
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#sns.relplot(data=tips,x='total_bill',y='tip',col='time'hue='smoker',style='smoker',size='size')
sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker',style='smoker',size='size',col='time')

# %%
dots=sns.load_dataset('dots')

# %%
print(dots)
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sns.relplot(data=dots,kind='line',x='time',y='firing_rate',col='align',hue='choice',size='coherence',
            style='choice',facet_kws=dict(sharex=False))

# %%
#statical estimation error bar
fmri=sns.load_dataset('fmri')
print(fmri)
#sns.relplot(data=fmri,kind='line',x='timepoint',y='signal',col='region',hue='event',style='event')
sns.relplot(data=fmri,kind='line',x='timepoint',y='signal',col='region',hue='event',style='event',facet_kws=dict(sharex=False))
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=dots,kind='line',x='time',y='firing_rate',col='align',hue='choice',
            size='coherence',style='choice',facet_kws=dict(sharex=False))

# %%
#sns.lmplot(data=tips,x=total_bill,y=tip,col='time',hue='smoker')
#print(tips)
sns.lmplot(data=tips,x='total_bill',y='tip',col='time',hue='smoker')

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")

# %%
import matplotlib.pyplot as plt
sns.plt.show()
#import plotly
sns.displots(data=tips,x='total_bill',y='tip',col='time',kde=True)
#print(tips)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-6612612005b6> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 sns.plt.show()
#       3 #import plotly
#       4 sns.displots(data=tips,x='total_bill',y='tip',col='time',kde=True)
#       5 #print(tips)
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
#sns.displot(data=tips, x="total_bill", col="time", kde=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-7950e7cfe499> in <module>
# ----> 1 sns.displot(data=tips, x="total_bill", col="time", kde=True)
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
sns.catplot(data=tips,kind='swarm',x='day',y='total_bill',hue='smoker')

# %%
sns.catplot(data=tips, kind="violin", x="bar",y="total_bill", hue="smoker")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-0d826e8df44c> in <module>
# ----> 1 sns.catplot(data=tips, kind="violin", x="bar" ,y="total_bill", hue="smoker")
#
# ~\Anaco\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3714     # facets to ensure representation of all data in the final plot
#    3715     p = _CategoricalPlotter()
# -> 3716     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3717     order = p.group_names
#    3718     hue_order = p.hue_names
#
# ~\Anaco\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
# ...

# %%
import matplotlib.pyplot as plt
sns.boxplot(x=tips["day"], y=tips["total_bill"],width=0.5)
#plt.show()

# %%
sns.catplot(data=tips, kind="bar", x="day",y="total_bill", hue="smoker")

# %%
#pang=sns.load_dataset('penguins')
#print(pang)
#sns.jointplot(data=penguins,x='flipper_length',y='bill_length_mm',hue='species')
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-155-5984779d737a> in <module>
#       3 #sns.jointplot(data=penguins,x='flipper_length',y='bill_length_mm',hue='species')
#       4 penguins = sns.load_dataset("penguins")
# ----> 5 sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")
#
# ~\Anaco\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2288
#    2289         joint_kws.setdefault("color", color)
# -> 2290         grid.plot_joint(plt.scatter, **joint_kws)
#    2291
#    2292         marginal_kws.setdefault("kde", False)
#
# ~\Anaco\lib\site-packages\seaborn\axisgrid.py in plot_joint(self, func, **kwargs)
#    1782         """
#    1783         plt.sca(self.ax_joint)
# ...

# %%
penguins = sns.load_dataset("penguins")
sns.(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-157-741389417139> in <module>
#       1 penguins = sns.load_dataset("penguins")
# ----> 2 sns.plot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-158-18c86d5dd634> in <module>
# ----> 1 sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
tip=sns.load_dataset('tips')
g=sns.relplot(data=tip,x='total_bill',y='tip')
g.ax.axline(xy1=(10,2),slope=-2,color=b,dashes=(5,2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-160-3405ec360f35> in <module>
#       1 tip=sns.load_dataset('tips')
#       2 g=sns.relplot(data=tip,x='total_bill',y='tip')
# ----> 3 g.ax.axline(xy1=(10,2),slope=-2,color=b,dashes=(5,2))
#
# AttributeError: 'AxesSubplot' object has no attribute 'axline'

# %%
fig,ax=plt.subplots()

# %%
g = sns.PairGrid(penguins, hue="species")
g.map_lower(sns.kdeplot, hue=None, levels=5, color=".2")
g.map_lower(sns.scatterplot, marker="+")
g.map_diag(sns.kdeplot, element="step", linewidth=0, kde=True)
g.add_legend(frameon=True)
g.legend.set_bbox_to_anchor((.61, .6))
#__init__
# Out:
# C:\Users\Raghav Jha\Anaco\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\Raghav Jha\Anaco\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-818f8c3ec1f5> in <module>
#       2 g.map_lower(sns.kdeplot, hue=None, levels=5, color=".2")
#       3 g.map_lower(sns.scatterplot, marker="+")
# ----> 4 g.map_diag(sns.kdeplot, element="step", linewidth=0, kde=True)
#       5 g.add_legend(frameon=True)
#       6 g.legend.set_bbox_to_anchor((.61, .6))
#
# ~\Anaco\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
# ...

# %%
#g=sns.pairgrid(penguins,hue='species')
#g.map_lower(sns.kdeplot,hue=None,level=5,color='.2')
sns.boxplot(x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-182-4f26b6f91571> in <module>
#       1 #g=sns.pairgrid(penguins,hue='species')
#       2 #g.map_lower(sns.kdeplot,hue=None,level=5,color='.2')
# ----> 3 sns.boxplot(x=df['speal length'])
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
g = sns.PairGrid(penguins, hue="species")
g.map_lower(sns.kdeplot, hue=None, levels=5, color=".2")
g.map_lower(sns.scatterplot, marker="+")
g.add_legend(frameon=True)
g.add_set_bbose_to_anchor((.61,.6))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-177-00bee4969011> in <module>
#       3 g.map_lower(sns.scatterplot, marker="+")
#       4 g.add_legend(frameon=True)
# ----> 5 g.add_set_bbose_to_anchor((.61,.6))
#
# AttributeError: 'PairGrid' object has no attribute 'add_set_bbose_to_anchor'

# %%
#sns.relplot(
 #   data=penguins,
  #  x="bill_length_mm", y="bill_depth_mm", hue="body_mass_g")

# %%
sns.relplot(data=penguins,x='bill_length__mm',y='bill_deoth_mm',hue='body_mass_g')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-04b417520a96> in <module>
# ----> 1 sns.relplot(data=penguins,x='bill_length__mm',y='bill_deoth_mm',hue='body_mass_g')
#
# ~\Anaco\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1574         sizes=sizes, size_order=size_order, size_norm=size_norm,
#    1575         markers=markers, dashes=dashes, style_order=style_order,
# -> 1576         legend=legend,
#    1577     )
#    1578
#
# ...

# %%
sns.color_palette("tab10")
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.boxplot(x=)

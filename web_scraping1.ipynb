# %%
item_name=[]
price=[]
import requests 
from bs4 import BeautifulSoup 
url='https://www.flipkart.com/laptops/~buyback-guarantee-on-laptops-/pr?sid=6bo%2Cb5g&uniqBStoreParam1=val1&wid=11.productCard.PMU_V2'
r=requests.get(url)
soup = BeautifulSoup(r.content,'html5lib')
#print(soup.prettify())
nav=soup.nav
#for url in nav.find_all('a'):
 #   print(url.get('href'))
#soup = BeautifulSoup(r.content, 'html5lib')

# %%
listings = soup.find_all('li', attrs={'class': 's-item'})
for listing in listings:
    prod_name=" "
    prod_price = " "
    for name in listing.find_all('h3', attrs={'class':"s-item__title"}):
        if(str(name.find(text=True, recursive=False))!="None"):
            prod_name=str(name.find(text=True, recursive=False))
            item_name.append(prod_name)
    if(prod_name!=" "):
            price = listing.find('span', attrs={'class':"s-item__price"})
            prod_price = str(price.find(text=True, recursive=False))
            prod_price = int(sub(",","",prod_price.split("INR")[1].split(".")[0]))
            prices.append(prod_price)
from scipy import stats
import numpy as np
 
data_note_8 = pd.DataFrame({"Name":item_name, "Prices": prices})
data_note_8 = data_note_8.iloc[np.abs(stats.zscore(data_note_8["Prices"]))&amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;lt; 3,]
# Out:
#   File "<ipython-input-20-5e31e8af2b97>", line 18
#     data_note_8 = data_note_8.iloc[np.abs(stats.zscore(data_note_8["Prices"]))&amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;lt; 3,]
#                                                                                   ^
# SyntaxError: invalid syntax

# %%
# importing modules 
import requests 
from bs4 import BeautifulSoup 

# URL for scrapping data 
url = 'https://www.worldometers.info/coronavirus/countries-where-coronavirus-has-spread/'

# get URL html 
page = requests.get(url) 
soup = BeautifulSoup(page.text, 'html.parser') 

soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]> <html lang="en" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->
# <!--[if !IE]><!--> <html lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Countries where Coronavirus has spread - Worldometer</title>
# <meta content="Where is Coronavirus in the world? List of countries with confirmed cases and deaths (total cumulative number) due to the novel coronavirus COVID-19" name="description"/>
# <link href="/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/favicon/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="http://www.worldometers.info/img/worldometers-fb.jpg" property="og:image">
# <link href="/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/wm16.css" rel="stylesheet"/>
# <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
# <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#       <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
# <script src="/js/jquery.min.js"></script>
# <script src="/js/bootstrap.min.js"></script>
# <script src="/js/ie10-viewport-bug-workaround.js"></script>
# <link href="https://cdn.datatables.net/1.10.19/css/dataTables.bootstrap.min.css" rel="stylesheet" type="text/css">
# <script src="https://cdn.datatables.net/1.10.19/js/jquery.dataTables.min.js" type="text/javascript"></script>
# <script src="https://cdn.datatables.net/1.10.19/js/dataTables.bootstrap.min.js" type="text/javascript"></script>
# <script class="init" type="text/javascript">
# 		$.extend( $.fn.dataTable.defaults, {
#     responsive: true
# } );
#
# 	$(document).ready(function() {
#     $('#example2').dataTable( {
#         "scrollCollapse": true,
# 		"sDom": '<"bottom"flp><"clear">',
#         "paging":         false
#     } );
# } );
# 	</script>
# <script class="init" type="text/javascript">
# 		$.extend( $.fn.dataTable.defaults, {
#     responsive: true
# } );
#
# 	$(document).ready(function() {
#     $('#table3').dataTable( {
#         "scrollCollapse": true,
# 				 "order": [[ 1, 'desc' ]],
# 		"sDom": '<"bottom"flp><"clear">',
#         "paging":         false
#     } );
# } );
# 	</script>
# <script class="init" type="text/javascript">
# 		$.extend( $.fn.dataTable.defaults, {
#     responsive: true
# } );
#
# 	$(document).ready(function() {
#     $('#example').dataTable( {
#         "scrollCollapse": true,
# 		"searching": false,
#
# 		"sDom": '<"top">rt<"bottom"flp><"clear">',
#         "paging":         false
#     } );
# } );
# 	</script>
# <script class="init" type="text/javascript">
# $(document).ready(function() {
# 	$('#popbycountry').dataTable();
# } );
# 	</script>
# <script data-cfasync="false" type="text/javascript">
#   var freestar = freestar || {};
#   freestar.hitTime = Date.now();
#   freestar.queue = freestar.queue || [];
#   freestar.config = freestar.config || {};
#   freestar.debug = window.location.search.indexOf('fsdebug') === -1 ? false : true;
#   freestar.config.enabled_slots = [];
#   !function(a,b){var c=b.getElementsByTagName("script")[0],d=b.createElement("script"),e="https://a.pub.network/worldometers-info";e+=freestar.debug?"/qa/pubfig.min.js":"/pubfig.min.js",d.async=!0,d.src=e,c.parentNode.insertBefore(d,c)}(window,document);
#   freestar.initCallback = function () { (freestar.config.enabled_slots.length === 0) ? freestar.initCallbackCalled = false : freestar.newAdSlots(freestar.config.enabled_slots) }
# </script>
# </link></meta></head>
# <body>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-1438574-2', 'auto');
#   ga('send', 'pageview');
# </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1438574-30"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-1438574-30');
# </script>
# <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.css" rel="stylesheet" type="text/css">
# <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.js"></script>
# <script>
# window.addEventListener("load", function(){
# window.cookieconsent.initialise({
#   "palette": {
#     "popup": {
#       "background": "#efefef",
#       "text": "#404040"
#     },
#     "button": {
#       "background": "#8ec760",
#       "text": "#ffffff"
#     }
#   },
#   "theme": "classic",
#   "content": {
#     "href": "http://www.worldometers.info/policy/"
#   }
# })});
# </script> <style type="text/css">
#     .style1 {
#         color: #666666
#     }
# </style>
# <div class="navbar navbar-default">
# <div class="container">
# <div class="navbar-header">
# <div class="logo"><a class="navbar-brand" href="/"><img border="0" src="/img/worldometers-logo.gif" title="Worldometer"/></a></div>
# <button class="navbar-toggle" data-target="#navbar-main" data-toggle="collapse" type="button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="navbar-collapse collapse" id="navbar-main">
# <ul class="nav navbar-nav">
# <li><a href="/coronavirus/"><span style="color:#FF9900; font-weight:bold">Coronavirus</span></a></li>
# <li><a href="/population/">Population</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div style="text-align:left; margin-bottom:10px">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-slot="3287840995" style="display:inline-block;width:970px;height:90px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </div>
# <div class="row"> <div class="col-md-8">
# <div class="content-inner">
# <style type="text/css">
#     .style1 {
#         font-weight: bold
#     }
#
#     .bold_number {
#         font-size: 18px;
#         font-weight: bold
#     }
# </style>
# <div class="label-counter"><a href="/coronavirus/">Coronavirus</a> / Countries</div>
# <div style="margin-top:20px; padding-bottom:10px; text-align:center; font-size:14px"><a href="/coronavirus/"><strong>UPDATES</strong></a> - <a href="/coronavirus/coronavirus-cases/"> </a><a href="/coronavirus/worldwide-graphs/">Graphs</a> - <a href="/coronavirus/#countries">Countries</a> - <a href="/coronavirus/coronavirus-death-rate/">Death Rate</a> - <a href="/coronavirus/coronavirus-incubation-period/">Incubation</a> - <a href="/coronavirus/coronavirus-age-sex-demographics/">Age</a> - <a href="/coronavirus/coronavirus-symptoms/">Symptoms</a></div>
# <div style="font-size:13px; color:#999; text-align:center">Last updated: October 07, 2020, 06:29 GMT</div>
# <h1>Countries where COVID-19 has spread </h1>
# <div style="margin-top:25px; margin-bottom:35px; font-size:17px; line-height: 1.7em;">
# <p>214</p></div></div></div></div></div></link></body></html> Countries and Territories around the world have reported a total of <span class="bold_number"><a href="/coronavirus/">36,052,635 confirmed cases</a></span> of the coronavirus COVID-19 that originated from Wuhan, China, and a death toll of <a href="/coronavirus/coronavirus-death-toll/"><strong>1,054,712 deaths</strong></a>.
# <p>For a more detailed list: <a href="/coronavirus/#countries"><strong>New cases, critical condition, and recovered by Country </strong></a></p>
#
# <style type="text/css">
#         <!--
#         .style1 {
#             font-size: 14px
#         }
#         -->
#     </style>
# <div class="table-responsive" style="padding-top:50px; font-size:16px; text-align:left; width:100%; max-width:600px;">
# <table cellspacing="0" class="table table-striped table-bordered" id="table3" text-align:left"="">
# <thead>
# <tr>
# <th width="70"><span class="style1">Country</span></th>
# <th width="30"><span class="style1">Cases</span></th>
# <th width="30"><span class="style1">Deaths</span></th>
# <th width="30"><span class="style1">Region</span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">United States</td>
# <td style="font-weight: bold; text-align:right">7,723,721</td>
# <td style="font-weight: bold; text-align:right">215,836</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">India</td>
# <td style="font-weight: bold; text-align:right">6,757,131</td>
# <td style="font-weight: bold; text-align:right">104,591</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Brazil</td>
# <td style="font-weight: bold; text-align:right">4,970,953</td>
# <td style="font-weight: bold; text-align:right">147,571</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Russia</td>
# <td style="font-weight: bold; text-align:right">1,237,504</td>
# <td style="font-weight: bold; text-align:right">21,663</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Colombia</td>
# <td style="font-weight: bold; text-align:right">869,808</td>
# <td style="font-weight: bold; text-align:right">27,017</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Spain</td>
# <td style="font-weight: bold; text-align:right">865,631</td>
# <td style="font-weight: bold; text-align:right">32,486</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Peru</td>
# <td style="font-weight: bold; text-align:right">832,929</td>
# <td style="font-weight: bold; text-align:right">32,914</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Argentina</td>
# <td style="font-weight: bold; text-align:right">824,468</td>
# <td style="font-weight: bold; text-align:right">21,827</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Mexico</td>
# <td style="font-weight: bold; text-align:right">794,608</td>
# <td style="font-weight: bold; text-align:right">82,348</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">South Africa</td>
# <td style="font-weight: bold; text-align:right">683,242</td>
# <td style="font-weight: bold; text-align:right">17,103</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">France</td>
# <td style="font-weight: bold; text-align:right">634,763</td>
# <td style="font-weight: bold; text-align:right">32,365</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">United Kingdom</td>
# <td style="font-weight: bold; text-align:right">530,113</td>
# <td style="font-weight: bold; text-align:right">42,445</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Iran</td>
# <td style="font-weight: bold; text-align:right">479,825</td>
# <td style="font-weight: bold; text-align:right">27,419</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Chile</td>
# <td style="font-weight: bold; text-align:right">473,306</td>
# <td style="font-weight: bold; text-align:right">13,070</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Iraq</td>
# <td style="font-weight: bold; text-align:right">387,121</td>
# <td style="font-weight: bold; text-align:right">9,531</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Bangladesh</td>
# <td style="font-weight: bold; text-align:right">371,631</td>
# <td style="font-weight: bold; text-align:right">5,405</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Saudi Arabia</td>
# <td style="font-weight: bold; text-align:right">337,243</td>
# <td style="font-weight: bold; text-align:right">4,923</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Italy</td>
# <td style="font-weight: bold; text-align:right">330,263</td>
# <td style="font-weight: bold; text-align:right">36,030</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Turkey</td>
# <td style="font-weight: bold; text-align:right">327,557</td>
# <td style="font-weight: bold; text-align:right">8,553</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Philippines</td>
# <td style="font-weight: bold; text-align:right">326,833</td>
# <td style="font-weight: bold; text-align:right">5,865</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Pakistan</td>
# <td style="font-weight: bold; text-align:right">316,351</td>
# <td style="font-weight: bold; text-align:right">6,535</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Indonesia</td>
# <td style="font-weight: bold; text-align:right">311,176</td>
# <td style="font-weight: bold; text-align:right">11,374</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Germany</td>
# <td style="font-weight: bold; text-align:right">307,119</td>
# <td style="font-weight: bold; text-align:right">9,635</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Israel</td>
# <td style="font-weight: bold; text-align:right">278,585</td>
# <td style="font-weight: bold; text-align:right">1,803</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Ukraine</td>
# <td style="font-weight: bold; text-align:right">239,337</td>
# <td style="font-weight: bold; text-align:right">4,597</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Canada</td>
# <td style="font-weight: bold; text-align:right">171,323</td>
# <td style="font-weight: bold; text-align:right">9,530</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Netherlands</td>
# <td style="font-weight: bold; text-align:right">144,999</td>
# <td style="font-weight: bold; text-align:right">6,482</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Ecuador</td>
# <td style="font-weight: bold; text-align:right">142,056</td>
# <td style="font-weight: bold; text-align:right">11,702</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Romania</td>
# <td style="font-weight: bold; text-align:right">139,612</td>
# <td style="font-weight: bold; text-align:right">5,121</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Bolivia</td>
# <td style="font-weight: bold; text-align:right">137,468</td>
# <td style="font-weight: bold; text-align:right">8,156</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Morocco</td>
# <td style="font-weight: bold; text-align:right">137,248</td>
# <td style="font-weight: bold; text-align:right">2,410</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Belgium</td>
# <td style="font-weight: bold; text-align:right">134,291</td>
# <td style="font-weight: bold; text-align:right">10,092</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Qatar</td>
# <td style="font-weight: bold; text-align:right">126,943</td>
# <td style="font-weight: bold; text-align:right">216</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Panama</td>
# <td style="font-weight: bold; text-align:right">116,602</td>
# <td style="font-weight: bold; text-align:right">2,440</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Dominican Republic</td>
# <td style="font-weight: bold; text-align:right">115,371</td>
# <td style="font-weight: bold; text-align:right">2,149</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Kazakhstan</td>
# <td style="font-weight: bold; text-align:right">108,362</td>
# <td style="font-weight: bold; text-align:right">1,746</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Kuwait</td>
# <td style="font-weight: bold; text-align:right">108,268</td>
# <td style="font-weight: bold; text-align:right">632</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Poland</td>
# <td style="font-weight: bold; text-align:right">104,316</td>
# <td style="font-weight: bold; text-align:right">2,717</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Egypt</td>
# <td style="font-weight: bold; text-align:right">103,902</td>
# <td style="font-weight: bold; text-align:right">6,001</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Oman</td>
# <td style="font-weight: bold; text-align:right">102,648</td>
# <td style="font-weight: bold; text-align:right">990</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">United Arab Emirates</td>
# <td style="font-weight: bold; text-align:right">100,794</td>
# <td style="font-weight: bold; text-align:right">435</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Sweden</td>
# <td style="font-weight: bold; text-align:right">96,145</td>
# <td style="font-weight: bold; text-align:right">5,883</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Guatemala</td>
# <td style="font-weight: bold; text-align:right">94,870</td>
# <td style="font-weight: bold; text-align:right">3,310</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Nepal</td>
# <td style="font-weight: bold; text-align:right">90,814</td>
# <td style="font-weight: bold; text-align:right">563</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Czech Republic (Czechia)</td>
# <td style="font-weight: bold; text-align:right">90,022</td>
# <td style="font-weight: bold; text-align:right">794</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Japan (+Diamond Princess)</td>
# <td style="font-weight: bold; text-align:right">86,759</td>
# <td style="font-weight: bold; text-align:right">1,615</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">China</td>
# <td style="font-weight: bold; text-align:right">85,489</td>
# <td style="font-weight: bold; text-align:right">4,634</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Costa Rica</td>
# <td style="font-weight: bold; text-align:right">82,142</td>
# <td style="font-weight: bold; text-align:right">1,004</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Belarus</td>
# <td style="font-weight: bold; text-align:right">81,090</td>
# <td style="font-weight: bold; text-align:right">868</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Honduras</td>
# <td style="font-weight: bold; text-align:right">80,662</td>
# <td style="font-weight: bold; text-align:right">2,447</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Portugal</td>
# <td style="font-weight: bold; text-align:right">80,312</td>
# <td style="font-weight: bold; text-align:right">2,032</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Ethiopia</td>
# <td style="font-weight: bold; text-align:right">80,003</td>
# <td style="font-weight: bold; text-align:right">1,238</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Venezuela</td>
# <td style="font-weight: bold; text-align:right">79,796</td>
# <td style="font-weight: bold; text-align:right">665</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Bahrain</td>
# <td style="font-weight: bold; text-align:right">73,476</td>
# <td style="font-weight: bold; text-align:right">262</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Nigeria</td>
# <td style="font-weight: bold; text-align:right">59,583</td>
# <td style="font-weight: bold; text-align:right">1,113</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Uzbekistan</td>
# <td style="font-weight: bold; text-align:right">59,579</td>
# <td style="font-weight: bold; text-align:right">491</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Singapore</td>
# <td style="font-weight: bold; text-align:right">57,830</td>
# <td style="font-weight: bold; text-align:right">27</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Moldova</td>
# <td style="font-weight: bold; text-align:right">57,732</td>
# <td style="font-weight: bold; text-align:right">1,389</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Switzerland</td>
# <td style="font-weight: bold; text-align:right">56,632</td>
# <td style="font-weight: bold; text-align:right">2,081</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Armenia</td>
# <td style="font-weight: bold; text-align:right">53,083</td>
# <td style="font-weight: bold; text-align:right">990</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Algeria</td>
# <td style="font-weight: bold; text-align:right">52,399</td>
# <td style="font-weight: bold; text-align:right">1,768</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Austria</td>
# <td style="font-weight: bold; text-align:right">49,819</td>
# <td style="font-weight: bold; text-align:right">822</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Kyrgyzstan</td>
# <td style="font-weight: bold; text-align:right">48,097</td>
# <td style="font-weight: bold; text-align:right">1,069</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Lebanon</td>
# <td style="font-weight: bold; text-align:right">46,918</td>
# <td style="font-weight: bold; text-align:right">424</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Ghana</td>
# <td style="font-weight: bold; text-align:right">46,829</td>
# <td style="font-weight: bold; text-align:right">303</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Paraguay</td>
# <td style="font-weight: bold; text-align:right">45,647</td>
# <td style="font-weight: bold; text-align:right">966</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">State of Palestine</td>
# <td style="font-weight: bold; text-align:right">42,432</td>
# <td style="font-weight: bold; text-align:right">349</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Azerbaijan</td>
# <td style="font-weight: bold; text-align:right">40,931</td>
# <td style="font-weight: bold; text-align:right">600</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Kenya</td>
# <td style="font-weight: bold; text-align:right">39,586</td>
# <td style="font-weight: bold; text-align:right">743</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Afghanistan</td>
# <td style="font-weight: bold; text-align:right">39,548</td>
# <td style="font-weight: bold; text-align:right">1,469</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Ireland</td>
# <td style="font-weight: bold; text-align:right">38,973</td>
# <td style="font-weight: bold; text-align:right">1,811</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Libya</td>
# <td style="font-weight: bold; text-align:right">38,468</td>
# <td style="font-weight: bold; text-align:right">602</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Serbia</td>
# <td style="font-weight: bold; text-align:right">34,072</td>
# <td style="font-weight: bold; text-align:right">757</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Hungary</td>
# <td style="font-weight: bold; text-align:right">32,298</td>
# <td style="font-weight: bold; text-align:right">853</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Denmark</td>
# <td style="font-weight: bold; text-align:right">30,379</td>
# <td style="font-weight: bold; text-align:right">663</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">El Salvador</td>
# <td style="font-weight: bold; text-align:right">29,634</td>
# <td style="font-weight: bold; text-align:right">873</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Bosnia and Herzegovina</td>
# <td style="font-weight: bold; text-align:right">28,710</td>
# <td style="font-weight: bold; text-align:right">903</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Australia</td>
# <td style="font-weight: bold; text-align:right">27,181</td>
# <td style="font-weight: bold; text-align:right">897</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Australia/Oceania</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">South Korea</td>
# <td style="font-weight: bold; text-align:right">24,353</td>
# <td style="font-weight: bold; text-align:right">425</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Bulgaria</td>
# <td style="font-weight: bold; text-align:right">22,306</td>
# <td style="font-weight: bold; text-align:right">862</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Tunisia</td>
# <td style="font-weight: bold; text-align:right">22,230</td>
# <td style="font-weight: bold; text-align:right">321</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Cameroon</td>
# <td style="font-weight: bold; text-align:right">20,924</td>
# <td style="font-weight: bold; text-align:right">420</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Greece</td>
# <td style="font-weight: bold; text-align:right">20,541</td>
# <td style="font-weight: bold; text-align:right">420</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Myanmar</td>
# <td style="font-weight: bold; text-align:right">20,033</td>
# <td style="font-weight: bold; text-align:right">471</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Côte d'Ivoire</td>
# <td style="font-weight: bold; text-align:right">19,903</td>
# <td style="font-weight: bold; text-align:right">120</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">North Macedonia</td>
# <td style="font-weight: bold; text-align:right">19,096</td>
# <td style="font-weight: bold; text-align:right">768</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Jordan</td>
# <td style="font-weight: bold; text-align:right">19,001</td>
# <td style="font-weight: bold; text-align:right">122</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Croatia</td>
# <td style="font-weight: bold; text-align:right">18,084</td>
# <td style="font-weight: bold; text-align:right">304</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Madagascar</td>
# <td style="font-weight: bold; text-align:right">16,600</td>
# <td style="font-weight: bold; text-align:right">234</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Zambia</td>
# <td style="font-weight: bold; text-align:right">15,170</td>
# <td style="font-weight: bold; text-align:right">335</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Senegal</td>
# <td style="font-weight: bold; text-align:right">15,141</td>
# <td style="font-weight: bold; text-align:right">312</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Norway</td>
# <td style="font-weight: bold; text-align:right">14,784</td>
# <td style="font-weight: bold; text-align:right">275</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Albania</td>
# <td style="font-weight: bold; text-align:right">14,568</td>
# <td style="font-weight: bold; text-align:right">403</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Slovakia</td>
# <td style="font-weight: bold; text-align:right">13,812</td>
# <td style="font-weight: bold; text-align:right">55</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Sudan</td>
# <td style="font-weight: bold; text-align:right">13,653</td>
# <td style="font-weight: bold; text-align:right">836</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Malaysia</td>
# <td style="font-weight: bold; text-align:right">13,504</td>
# <td style="font-weight: bold; text-align:right">141</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Montenegro</td>
# <td style="font-weight: bold; text-align:right">12,584</td>
# <td style="font-weight: bold; text-align:right">188</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Namibia</td>
# <td style="font-weight: bold; text-align:right">11,673</td>
# <td style="font-weight: bold; text-align:right">125</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Finland</td>
# <td style="font-weight: bold; text-align:right">10,929</td>
# <td style="font-weight: bold; text-align:right">346</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Guinea</td>
# <td style="font-weight: bold; text-align:right">10,863</td>
# <td style="font-weight: bold; text-align:right">68</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">DR Congo</td>
# <td style="font-weight: bold; text-align:right">10,789</td>
# <td style="font-weight: bold; text-align:right">274</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Maldives</td>
# <td style="font-weight: bold; text-align:right">10,621</td>
# <td style="font-weight: bold; text-align:right">34</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">French Guiana</td>
# <td style="font-weight: bold; text-align:right">10,070</td>
# <td style="font-weight: bold; text-align:right">69</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Tajikistan</td>
# <td style="font-weight: bold; text-align:right">10,014</td>
# <td style="font-weight: bold; text-align:right">78</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Mozambique</td>
# <td style="font-weight: bold; text-align:right">9,398</td>
# <td style="font-weight: bold; text-align:right">67</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Georgia</td>
# <td style="font-weight: bold; text-align:right">9,245</td>
# <td style="font-weight: bold; text-align:right">58</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Uganda</td>
# <td style="font-weight: bold; text-align:right">9,082</td>
# <td style="font-weight: bold; text-align:right">84</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Luxembourg</td>
# <td style="font-weight: bold; text-align:right">8,979</td>
# <td style="font-weight: bold; text-align:right">128</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Haiti</td>
# <td style="font-weight: bold; text-align:right">8,838</td>
# <td style="font-weight: bold; text-align:right">229</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Gabon</td>
# <td style="font-weight: bold; text-align:right">8,808</td>
# <td style="font-weight: bold; text-align:right">54</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Zimbabwe</td>
# <td style="font-weight: bold; text-align:right">7,915</td>
# <td style="font-weight: bold; text-align:right">229</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Mauritania</td>
# <td style="font-weight: bold; text-align:right">7,529</td>
# <td style="font-weight: bold; text-align:right">162</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Jamaica</td>
# <td style="font-weight: bold; text-align:right">7,109</td>
# <td style="font-weight: bold; text-align:right">123</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Slovenia</td>
# <td style="font-weight: bold; text-align:right">6,764</td>
# <td style="font-weight: bold; text-align:right">159</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Cabo Verde</td>
# <td style="font-weight: bold; text-align:right">6,518</td>
# <td style="font-weight: bold; text-align:right">69</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# ...
# <td style="font-weight: bold; text-align:right">200</td>
# <td style="font-weight: bold; text-align:right">7</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Bermuda</td>
# <td style="font-weight: bold; text-align:right">181</td>
# <td style="font-weight: bold; text-align:right">9</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Seychelles</td>
# <td style="font-weight: bold; text-align:right">148</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Brunei </td>
# <td style="font-weight: bold; text-align:right">146</td>
# <td style="font-weight: bold; text-align:right">3</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Caribbean Netherlands</td>
# <td style="font-weight: bold; text-align:right">141</td>
# <td style="font-weight: bold; text-align:right">2</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Liechtenstein</td>
# <td style="font-weight: bold; text-align:right">130</td>
# <td style="font-weight: bold; text-align:right">1</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Antigua and Barbuda</td>
# <td style="font-weight: bold; text-align:right">108</td>
# <td style="font-weight: bold; text-align:right">3</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">British Virgin Islands</td>
# <td style="font-weight: bold; text-align:right">71</td>
# <td style="font-weight: bold; text-align:right">1</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">St. Vincent &amp; Grenadines</td>
# <td style="font-weight: bold; text-align:right">64</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Saint Barthelemy</td>
# <td style="font-weight: bold; text-align:right">62</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Macao</td>
# <td style="font-weight: bold; text-align:right">46</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Fiji</td>
# <td style="font-weight: bold; text-align:right">32</td>
# <td style="font-weight: bold; text-align:right">2</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Australia/Oceania</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Dominica</td>
# <td style="font-weight: bold; text-align:right">31</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Timor-Leste</td>
# <td style="font-weight: bold; text-align:right">28</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Saint Lucia</td>
# <td style="font-weight: bold; text-align:right">27</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">New Caledonia</td>
# <td style="font-weight: bold; text-align:right">27</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Australia/Oceania</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Grenada</td>
# <td style="font-weight: bold; text-align:right">24</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Laos</td>
# <td style="font-weight: bold; text-align:right">23</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Asia</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Saint Kitts &amp; Nevis</td>
# <td style="font-weight: bold; text-align:right">19</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Saint Pierre &amp; Miquelon</td>
# <td style="font-weight: bold; text-align:right">16</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Greenland</td>
# <td style="font-weight: bold; text-align:right">14</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Montserrat</td>
# <td style="font-weight: bold; text-align:right">13</td>
# <td style="font-weight: bold; text-align:right">1</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Falkland Islands</td>
# <td style="font-weight: bold; text-align:right">13</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">South America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Holy See</td>
# <td style="font-weight: bold; text-align:right">12</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Europe</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Western Sahara</td>
# <td style="font-weight: bold; text-align:right">10</td>
# <td style="font-weight: bold; text-align:right">1</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Africa</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">MS Zaandam</td>
# <td style="font-weight: bold; text-align:right">9</td>
# <td style="font-weight: bold; text-align:right">2</td>
# <td style="font-size:14px; color:#aaa; text-align:right"></td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Anguilla</td>
# <td style="font-weight: bold; text-align:right">3</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">North America</td>
# </tr>
# <tr>
# <td style="font-weight: bold; font-size:16px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">Solomon Islands</td>
# <td style="font-weight: bold; text-align:right">1</td>
# <td style="font-weight: bold; text-align:right">0</td>
# <td style="font-size:14px; color:#aaa; text-align:right">Australia/Oceania</td>
# </tr>
# </tbody>
# </table>
# <br/>
# </div>
# <h2>Coronavirus Worldometer Sections:</h2>
# <div class="spaced" style="margin-top:20px ">
# <ul>
# <li><a href="/coronavirus/"><strong>Coronavirus Update</strong></a></li>
# <li><a href="/coronavirus/coronavirus-cases/"><strong>Case statistics and graphs</strong></a></li>
# <li><a href="/coronavirus/coronavirus-death-toll/"><strong>Death statistics and graphs</strong></a></li>
# <li><a href="/coronavirus/coronavirus-death-rate/"><strong>Mortality Rate</strong></a></li>
# <li><strong><a href="/coronavirus/coronavirus-incubation-period/">Incubation Period</a></strong></li>
# <li><strong><a href="/coronavirus/coronavirus-age-sex-demographics/"><strong>Age, Sex, Existing Condition</strong></a></strong></li>
# <li><strong><a href="/coronavirus/coronavirus-symptoms/">Symptoms</a></strong></li>
# <li><strong>Countries with cases: <a href="/coronavirus/countries-where-coronavirus-has-spread/">basic list</a></strong> - <a href="/coronavirus/#countries"><strong>detailed list</strong></a></li>
# </ul>
# </div>
#
# <div class="col-md-4 adright"><div>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-slot="2348228155" style="display:inline-block;width:300px;height:600px"></ins>
# <script>
# 	(adsbygoogle = window.adsbygoogle || []).push({});
# 	</script>
# </div>
# <div style="padding-left:25px">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-slot="2348228155" style="display:inline-block;width:300px;height:600px"></ins>
# <script>
# 	(adsbygoogle = window.adsbygoogle || []).push({});
# 	</script>
# </div>
# <div style="margin-top:40px; margin-bottom:40px; padding-left:25px">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-format="auto" data-ad-slot="4941262260" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# <div style="margin-top:40px; margin-bottom:40px; padding-left:25px">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-format="auto" data-ad-slot="4941262260" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# <div style="margin-top:40px; margin-bottom:40px; padding-left:25px">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-slot="9468680730" style="display:inline-block;width:160px;height:600px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# <div style="margin-top:80px; padding-left:40px; margin-bottom:40px">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-slot="2348228155" style="display:inline-block;width:300px;height:600px"></ins>
# <script>
# 	(adsbygoogle = window.adsbygoogle || []).push({});
# 	</script>
# </div>
# <div style="margin-top:80px; padding-left:40px; margin-bottom:40px">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-format="auto" data-ad-slot="4941262260" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </div>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-format="auto" data-ad-slot="6995709761" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <div style="margin-top:40px"></div>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3701697624350410" data-ad-format="auto" data-ad-slot="1743383089" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
#
# <footer>
# <div class="footerlinks">
# <div style="margin-bottom:20px"><a href="/"><img border="0" class="img-footer" src="/img/worldometers-logo-footer.png"/></a></div>
# <a href="/about/">about</a> | <a href="/faq/">faq</a> | <a href="/languages/">languages</a> | <a href="/contact/">contact</a>
# </div>
# <ul class="list-inline text-center socialbuttons">
# <li><a data-placement="bottom" data-toggle="tooltip" href="/newsletter-subscribe/" title="Newsletter"><i class="fa fa-bullhorn fa-round"></i></a></li>
# <li><a href="https://twitter.com/Worldometers"><i class="fa fa-twitter fa-round"></i></a></li>
# <li><a href="https://www.facebook.com/Worldometers.info"><i class="fa fa-facebook fa-round"></i></a></li>
# </ul>
# <div class="copy">© Copyright Worldometers.info - All rights reserved - <a href="/disclaimer/">Disclaimer &amp; Privacy Policy</a></div>
# </footer>
# <script async="async" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54615fa823b2af68" type="text/javascript"></script>
# <script type="text/javascript">
#     (function() {
#         function async_load(script_url){
#             var protocol = ('https:' == document.location.protocol ? 'https://' : 'http://');
#             var s = document.createElement('script'); s.src = protocol + script_url;
#             var x = document.getElementsByTagName('script')[0]; x.parentNode.insertBefore(s, x);
#         }
#         bm_website_code = '7849CD9451D34931';
#         jQuery(document).ready(function(){async_load('asset.pagefair.com/measure.min.js')});
#         jQuery(document).ready(function(){async_load('asset.pagefair.net/ads.min.js')});
#     })();
# </script>
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-Pd9JxUkvV0m7q"
# });
# </script>
# <noscript>
# <div style="display:none;">
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-Pd9JxUkvV0m7q.gif" width="1">
# </img></div>
# </noscript>

# %%
# create texttable object 
table = tt.Texttable() 
table.add_rows([(None, None, None, None)] + data) # Add an empty row at the beginning for the headers 
table.set_cols_align(('c', 'c', 'c', 'c')) # 'l' denotes left, 'c' denotes center, and 'r' denotes right 
table.header((' Country ', ' Number of cases ', ' Deaths ', ' Continent ')) 

print(table.draw())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f36bad4166bc> in <module>
#       1 # create texttable object
# ----> 2 table = tt.Texttable()
#       3 table.add_rows([(None, None, None, None)] + data) # Add an empty row at the beginning for the headers
#       4 table.set_cols_align(('c', 'c', 'c', 'c')) # 'l' denotes left, 'c' denotes center, and 'r' denotes right
#       5 table.header((' Country ', ' Number of cases ', ' Deaths ', ' Continent '))
#
# NameError: name 'tt' is not defined

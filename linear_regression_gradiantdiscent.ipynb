# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
test=pd.read_csv('testscore.csv')

# %%
test
# Out:
#    math_score  cs_score
# 0          65        69
# 1          78        58
# 2          96        89
# 3          41        56
# 4          46        25
# 5          78        89
# 6          56        85
# 7          75        45
# 8          89        99

# %%
x=test['math_score']
y=test['cs_score']

# %%
#apply gradiant discent
def gradint_discen(x,y):
    pass
my_curr,b_curr=0,0
iteration=1000
n=len(x)
learn_rate=0.03
for i in range(iteration):
    y_predict=my_curr*x+b_curr
    cost=(1/n)*sum([val**2 for val in (y-y_predcit)])
    md=-(2/n)*sum(y-y_pred)
    #md = -(2/n)*sum(x*(y-y_predicted))
    bd = -(2/n)*sum(y-y_pred)
    m_curr = m_curr - learning_rate * md
    b_curr=b_curr - learning_rate * bd
    print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-9c9e3f2c4971> in <module>
#       8 for i in range(iteration):
#       9     y_predict=my_curr*x+b_curr
# ---> 10     cost=(1/n)*sum([val**2 for val in (y-y_predcit)])
#      11     md=-(2/n)*sum(y-y_pred)
#      12     #md = -(2/n)*sum(x*(y-y_predicted))
#
# NameError: name 'y_predcit' is not defined

# %%
import numpy as np
def gradian_discent(x,y):
    m_curr,b_curr=0
    iteration=1000
    n=len(x)
    learning_rate=0.01
    for i in range(iteration):
        y_predict=my_curr*x+b_curr
        cost=(1/n)*sum(x*(y-y_predict))
        md=-(2/n)*sum(y-y_predict)
        bd=-(2/n)*sum(y-y_predicted)
        my_curr=my_curr-learning_rate*md
        b_curr=b_curr-learning_rate*bd
        print('m {} ,b{},cost{} iteration{}'.format(m_curr,b_curr,cost,i))
x=test['math_score']
y=test['cs_score']
gradian_discent(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-d9f9023bd937> in <module>
#      15 x=test['math_score']
#      16 y=test['cs_score']
# ---> 17 gradian_discent(x,y)
#
# <ipython-input-49-d9f9023bd937> in gradian_discent(x, y)
#       1 import numpy as np
#       2 def gradian_discent(x,y):
# ----> 3     m_curr,b_curr=0
#       4     iteration=1000
#       5     n=len(x)
#
# TypeError: cannot unpack non-iterable int object

# %%
x=test['math_score']
y=test['cs_score']
import numpy as np
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 10
    n = len(x)
    learning_rate = 0.01
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 0.62, b 0.18, cost 89.0 iteration 0
# m 1.0928, b 0.3192, cost 52.25039999999999 iteration 1
# m 1.453232, b 0.42724799999999996, cost 30.831949440000002 iteration 2
# m 1.7278860800000002, b 0.5115091199999999, cost 18.347751350784 iteration 3
# m 1.9370605952000002, b 0.5776057727999999, cost 11.070010749324897 iteration 4
# m 2.096250917888, b 0.6298300216319999, cost 6.826353152519786 iteration 5
# m 2.2172859146547204, b 0.6714583661260799, cost 4.350826141683065 iteration 6
# m 2.309195511463117, b 0.7049920439242751, cost 2.9056952040975976 iteration 7
# m 2.3788729763057748, b 0.7323404723580026, cost 2.0610450731046615 iteration 8
# m 2.431580493177024, b 0.7549612843324961, cost 1.5663423003130599 iteration 9

# %%
def gradiant(x,y):
    m=0
    c=0
    iteration=1000
    learning_rate=0.0001
    for i in range(iteration):
        dist=m*x+c
        cost=(1/n)*sum([val**2 for val in (y-dist)])
        md=-(2/n)*sum(x*(y-dist))
        bd=-(2/n)*sum(y)

# %%
def gradiant(x,y):
    m=0
    c=0
    iteration=1000
    learning_rate=0.001
   # dist=m*x+c
    for i in range(iteration):
        dist=m*x+c
        cost = (1/n) * sum([val**2 for val in (y-dist)])
        md = -(2/n)*sum(x*(y-dist))
        bd = -(2/n)*sum(y-dist)
        mrate=m - learning_rate * md
        brate=m-learning_rate*bd
        print ("m {}, b {}, cost {} iteration {}".format(mrate,brate,cost, i))
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,1,8])
gradiant(x,y)
# Out:
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 0
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 1
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 2
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 3
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 4
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 5
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 6
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 7
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 8
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 9
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 10
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 11
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 12
# m 0.02, b 0.006666666666666666, cost 24.444444444444443 iteration 13
# ...
